# %%
import pandas as pd

# %%
# ============================================================
# SHEET 1: GLOBAL INDICES & MACRO INDICATORS
# ============================================================
global_indices_data = [
    ["S&P 500", "USA", "US close (~1:30-4:00 AM IST)", "Risk-off, FII outflows, Nifty likely weak", "Risk-on, FII inflows, Nifty likely strong", "Most powerful global trendsetter; drives global risk appetite", "Broad market, IT, Financials", "Align trades with US direction; avoid counter-trend longs on red days", "Watch futures if US closed"],
    ["Nasdaq Composite", "USA", "US close", "Tech sell-off, pressure on Indian IT", "Tech rally, support for Indian IT", "Directly impacts Indian IT sector", "IT, Tech", "Avoid IT longs if Nasdaq red; consider IT shorts", "IT stocks have high beta to Nasdaq"],
    ["Dow Jones", "USA", "US close", "Industrial/blue-chip weakness, negative sentiment", "Industrial/blue-chip strength, positive sentiment", "Reflects global industrial and blue-chip health", "Industrials, Financials", "Use as confirmation of S&P trend", "Less volatile than Nasdaq"],
    ["FTSE 100", "UK/Europe", "European open ~12:30 PM IST", "European weakness, pressure on metals", "European strength, support for metals", "Signals European economic trends", "Metals, Commodities, Energy", "Adjust afternoon bias based on FTSE", "Influences commodity-linked stocks"],
    ["DAX", "Germany", "European open ~12:30 PM IST", "EU weakness, export pressure", "EU strength, export support", "Key indicator of European economic strength", "Auto, Metals, Exporters", "Watch for afternoon trend confirmation", "Germany is major trading partner"],
    ["Nikkei 225", "Japan", "Asian open ~5:30 AM IST", "Asian risk-off, early weakness", "Asian risk-on, early strength", "Leading Asian market; sets early tone", "Broad market", "Use for early bias before GIFT Nifty", "Volatility spillover to India"],
    ["Hang Seng", "Hong Kong/China", "Asian open ~7:00 AM IST", "China/Asia weakness, commodity pressure", "China/Asia strength, commodity support", "Reflects Asian sentiment and China demand", "Commodities, Metals", "Lower correlation than US; use as secondary", "Watch China policy news"],
    ["GIFT Nifty", "India proxy", "24/5, especially 7:00-9:00 AM IST", "Weak opening expected", "Strong opening expected", "Directly reflects expected Nifty opening", "All sectors", "Primary pre-market indicator; set opening bias", "Formerly SGX Nifty"],
    ["MSCI Emerging Markets", "Global", "During global hours", "EM outflows, negative for India", "EM inflows, positive for India", "Guides global fund allocation to EMs", "Large caps, Financials", "Follow for FII flow direction", "India weight ~11-12%"],
    ["US Dollar Index (DXY)", "Global", "24/5", "Strong dollar: FII outflows, pressure on Nifty", "Weak dollar: FII inflows, support for Nifty", "Inverse relationship with Indian markets", "IT (weak rupee positive), Importers", "Strong dollar = bearish bias; weak dollar = bullish", "Watch DXY before market"],
    ["Crude Oil (Brent)", "Global", "24/5", "Falling oil: positive for India", "Rising oil: negative for India", "Inverse relationship due to import dependence", "Oil marketing, Aviation, Paints, Tyres", "Falling oil = bullish; rising oil = bearish", "India imports ~85% of oil"],
    ["Gold", "Global", "24/5", "Falling gold: risk-on, equities up", "Rising gold: risk-off, equities down", "Safe-haven asset; negative correlation with equities", "Jewellery", "Use as risk sentiment gauge", "Not a direct driver but signals mood"],
    ["India VIX", "India", "9:15-3:30 PM IST", "Falling VIX: complacency, bullish", "Rising VIX: fear, bearish", "Volatility gauge for Indian market", "All sectors", "Use for position sizing; high VIX = smaller size", "Above 20 = high fear"],
    ["FII/DII Data", "India", "After market ~6 PM IST", "FII selling: negative", "FII buying: positive", "Institutional flows drive liquidity", "Large caps", "Follow FIIs for trend confirmation", "DII often counters FII"],
    ["USD/INR", "India", "9:00-5:00 PM IST", "Rupee strengthening: positive for importers", "Rupee weakening: positive for IT, negative for importers", "Currency impacts earnings and flows", "IT, Pharma, Importers", "Weak rupee = IT bullish; strong rupee = importers bullish", "Watch RBI intervention"],
    ["US 10-Year Treasury Yield", "USA", "24/5", "Falling yields: risk-on, EM inflows", "Rising yields: risk-off, EM outflows", "Global cost of capital", "Financials, Realty", "Rising yields = bearish for EMs", "Key global liquidity indicator"],
]

columns_global = ["Indicator/Index", "Region", "When to Watch (IST)", "If RED (Down)", "If GREEN (Up)", "Impact on Indian Market", "Key Sectors Affected", "Trade Action/Bias", "Notes"]
df_global = pd.DataFrame(global_indices_data, columns=columns_global)

# %%
# ============================================================
# SHEET 2: TECHNICAL INDICATORS & STRATEGIES
# ============================================================
indicators_data = [
    ["EMA (20, 50, 200)", "Trend direction", "Price above EMA = bullish", "Price below EMA = bearish", "15m, 1h, Daily", "Multiple EMAs confirm trend", "Buy pullbacks to 20 EMA in uptrend; sell rallies to 20 EMA in downtrend", "Golden cross (50>200) bullish; death cross bearish"],
    ["RSI (14)", "Momentum", ">70 overbought; <30 oversold; bullish divergence", "Bearish divergence; failure at 70", "15m, 1h, Daily", "Confirms momentum and divergences", "Buy oversold in uptrend; sell overbought in downtrend", "Use with trend, not alone"],
    ["MACD", "Momentum and trend", "MACD line crosses above signal; histogram positive", "MACD crosses below signal; histogram negative", "1h, Daily", "Confirms trend changes", "Buy when MACD crosses above signal in uptrend", "Lagging indicator; use with price"],
    ["VWAP", "Intraday fair value", "Price above VWAP = bullish", "Price below VWAP = bearish", "5m, 15m", "Intraday bias", "Long above VWAP, short below", "Institutional benchmark"],
    ["Bollinger Bands", "Volatility", "Price at lower band + reversal = buy", "Price at upper band + reversal = sell", "15m, 1h, Daily", "Volatility expansion/contraction", "Buy breakout after squeeze", "Squeeze signals big move"],
    ["ADX", "Trend strength", ">25 trending", "<20 ranging", "1h, Daily", "Filter trend vs range", "Use trend strategies when ADX>25", "Doesn't show direction"],
    ["Volume", "Participation", "High volume confirms breakout", "Low volume warns of fakeout", "Daily, Intraday", "Confirms price action", "Avoid low-volume breakouts", "Volume precedes price"],
    ["Support/Resistance", "Price levels", "Bounce from support", "Rejection at resistance", "All", "Key levels for entries/exits", "Buy at support, sell at resistance", "Use multiple timeframes"],
    ["Fibonacci Retracement", "Pullback levels", "38.2%, 50%, 61.8% support in uptrend", "Resistance in downtrend", "1h, Daily", "Entry levels", "Buy at 50-61.8% in uptrend", "Draw from swing low to high"],
    ["Pivot Points", "Intraday levels", "Price above pivot = bullish", "Price below pivot = bearish", "Daily", "Intraday bias", "Trade according to pivot", "R1/R2/S1/S2"],
    ["Open Interest (OI)", "Futures positioning", "Rising OI + rising price = long buildup", "Rising OI + falling price = short buildup", "Daily", "Confirms trend", "Follow long buildup", "Watch for short covering"],
    ["Put-Call Ratio (PCR)", "Sentiment", ">1.2 overbought (contrarian)", "<0.7 oversold (contrarian)", "Daily", "Contrarian indicator", "Use with price action", "Extreme readings signal reversal"],
    ["India VIX", "Volatility", "Falling VIX = calm", "Rising VIX = fear", "Daily", "Risk management", "Reduce size when VIX high", "Above 20 = high risk"],
    ["FII/DII Data", "Institutional flow", "Net buying = bullish", "Net selling = bearish", "Daily", "Confirms trend", "Follow FIIs for large caps", "DII can counter"],
]

columns_ind = ["Indicator", "What it Measures", "Bullish Signal", "Bearish Signal", "Best Timeframe", "How to Use for Overall Picture", "Trade Action", "Notes"]
df_ind = pd.DataFrame(indicators_data, columns=columns_ind)

# %%
# ============================================================
# SHEET 3: STRATEGY PLAYBOOK
# ============================================================
playbook_data = [
    ["Bullish Day", "US up, GIFT Nifty up, Asia up", "Falling", "Price above VWAP, EMA20>50", "Buy dips to support/EMA", "Stop below day low; target R1/R2"],
    ["Bearish Day", "US down, GIFT Nifty down, Asia down", "Rising", "Price below VWAP, EMA20<50", "Short rallies to resistance", "Stop above day high; target S1/S2"],
    ["Range Day", "Mixed global cues", "Low", "ADX<20, price between S1/R1", "Buy support, sell resistance", "Small targets; tight stops"],
    ["Event Day", "Fed, CPI, Budget", "High", "Avoid before event", "Wait for direction", "Tight stops; reduce size"],
    ["Trend Reversal", "RSI divergence, MACD cross", "Spiking", "Volume spike, price action", "Enter after confirmation", "Stop below swing"],
]

columns_play = ["Scenario", "Global Cues", "India VIX", "Technical Setup", "Trade Action", "Risk Management"]
df_play = pd.DataFrame(playbook_data, columns=columns_play)

# %%
# ============================================================
# SHEET 4: DAILY ROUTINE CHECKLIST
# ============================================================
routine_data = [
    ["6:00-7:00 AM", "Check US close, GIFT Nifty, Asian markets", "US indices, GIFT Nifty, Nikkei, Hang Seng", "Note bullish/bearish bias"],
    ["8:00-9:00 AM", "Check news, FII/DII, USD/INR, crude", "News, DXY, Crude, USD/INR", "Adjust bias"],
    ["9:00-9:15 AM", "Check pre-market, GIFT Nifty final", "GIFT Nifty, pre-open data", "Plan trades"],
    ["9:15-9:30 AM", "Observe opening, VWAP, volume", "Opening range, VWAP", "Wait for setup"],
    ["12:30-1:00 PM", "Check European open", "FTSE, DAX", "Adjust intraday bias"],
    ["2:00-3:00 PM", "Check US futures", "US futures", "Manage trades"],
    ["3:30 PM", "Review trades, note FII/DII", "FII/DII data", "Journal"],
]

columns_routine = ["Time (IST)", "Action", "What to Check", "Decision"]
df_routine = pd.DataFrame(routine_data, columns=columns_routine)

# %%
# ============================================================
# CREATE EXCEL FILE
# ============================================================
filename = "Global_Market_India_Playbook.xlsx"

with pd.ExcelWriter(filename, engine="openpyxl") as writer:
    df_global.to_excel(writer, sheet_name="Global_Indices_Macro", index=False)
    df_ind.to_excel(writer, sheet_name="Technical_Indicators", index=False)
    df_play.to_excel(writer, sheet_name="Strategy_Playbook", index=False)
    df_routine.to_excel(writer, sheet_name="Daily_Routine", index=False)
    
    # Auto-adjust column widths
    for sheet_name in writer.sheets:
        worksheet = writer.sheets[sheet_name]
        for column in worksheet.columns:
            max_length = 0
            column_letter = column[0].column_letter
            for cell in column:
                try:
                    if len(str(cell.value)) > max_length:
                        max_length = len(str(cell.value))
                except:
                    pass
            adjusted_width = min(max_length + 2, 50)
            worksheet.column_dimensions[column_letter].width = adjusted_width

print(f"Excel file '{filename}' created successfully!")
# Out:
# Excel file 'Global_Market_India_Playbook.xlsx' created successfully!
